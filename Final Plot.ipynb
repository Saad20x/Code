# %%
import pandas as pd
import numpy as np
import seaborn as sb

df = pd.read_csv('C:/Users/Saad/Downloads/Alassandro Discord/poland_august.csv')
df.head()
# Out:
#     latitude  longitude
# 0  52.307691  21.080570
# 1  52.172312  21.069810
# 2  52.132664  21.109540
# 3  52.306070  20.993825
# 4  52.158364  21.053007

# %%
heat_map = sb.heatmap(df)

# %%
import matplotlib.pyplot as plt

x = df["latitude"].values
y = df["longitude"].values

plt.scatter(x,y)
plt.show()

# %%
import numpy as np
import pandas as pd
import folium as fo
df = pd.read_csv('C:/Users/Saad/Downloads/Alassandro Discord/gdansk_august.csv')
df.head()
# Out:
#     latitude  longitude
# 0  54.354057  18.505110
# 1  54.349739  18.531541
# 2  54.349931  18.531515
# 3  54.447835  18.563724
# 4  54.349931  18.531515

# %%
lat = list(df["latitude"])
lon = list(df["longitude"])

# %%
volcano = fo.FeatureGroup(df="Volcano")
for a, b, in zip(lat, lon):
  volcano.add_child(fo.Marker(location=[a, b], icon=fo.Icon(color='blue')))
  
fo.Map().add_child(volcano)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sb

df = pd.read_csv('C:/Users/Saad/Downloads/Alassandro Discord/poland_august.csv')
df
# Out:
#        latitude  longitude
# 0     52.307691  21.080570
# 1     52.172312  21.069810
# 2     52.132664  21.109540
# 3     52.306070  20.993825
# 4     52.158364  21.053007
# ...         ...        ...
# 2045  52.317268  20.968451
# 2046  52.207007  20.895874
# 2047  52.171730  21.164751
# 2048  52.319306  20.966293
# 2049  52.227509  20.975298
#
# [2050 rows x 2 columns]

# %%
import folium

# %%
lats = df['latitude']
lons = df['longitude']

# %%
lats
# Out:
# 0       52.307691
# 1       52.172312
# 2       52.132664
# 3       52.306070
# 4       52.158364
#           ...
# 2045    52.317268
# 2046    52.207007
# 2047    52.171730
# 2048    52.319306
# 2049    52.227509
# Name: latitude, Length: 2050, dtype: float64

# %%
a = folium.Map(location=[lats[0], lons[0]])

# %%
for lat, lon in zip (lats, lons):
    
    heatmap_data = (location =[lat, lon],
    popup = lat, lon,
    icon=folium.Icon(color='green')).add_to(a)

# %%
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\folium\folium.py in _repr_html_(self, **kwargs)
#     297             self._parent = None
#     298         else:
# --> 299             out = self._parent._repr_html_(**kwargs)
#     300         return out
#     301
#
# ~\anaconda3\lib\site-packages\branca\element.py in _repr_html_(self, **kwargs)
#     329
#     330         """
# --> 331         html = urllib.parse.quote(self.render(**kwargs))
#     332         onload = (
#     333             'this.contentDocument.open();'
#
# ...
